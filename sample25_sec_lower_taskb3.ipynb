# %% [markdown]
# # Task B3 — Simple Rule-based Agents (NumPy)
# Lower Secondary / Section B — Programming + Theory
#
# Scope:
# - Define the agent loop (sense → plan → act) with clear goals and limits.
# - Build a simple rule/block‑based agent to complete a task; test edge cases.
# - Use human‑in‑the‑loop approvals and privacy‑by‑design for safe actions.

# %% [markdown]
# ## Theory Prompts
# 1. Draw the sense → plan → act loop and list two tracked items (e.g., steps, approvals).
# 2. Explain why an approval step reduces risk in school contexts.
# 3. Identify one privacy-by-design choice when handling arrays of scores.

# %%
import numpy as np

# %% [markdown]
# ## Provided Tasks (array sandbox)

# %%
# DO NOT MODIFY
TASKS = [
    {'name':'sum small list','type':'sum','input': np.array([1,2,3]), 'approved': True},
    {'name':'flag highs','type':'threshold','input': np.array([0.3, 0.7, 0.2]), 'threshold': 0.5, 'approved': True},
    {'name':'sum needs approval','type':'sum','input': np.array([5,5]), 'approved': False}
]
MAX_STEPS = 2
ALLOWED_TOOLS = {'sum_array','threshold_flag'}

# %% [markdown]
# ## Tools (NumPy-only)

# %%
def sum_array(arr: np.ndarray):
    """Return sum(arr) as float using NumPy.
    """
    pass
def threshold_flag(arr: np.ndarray, threshold: float=0.5):
    """Return integer flags where arr >= threshold.
    """
    pass

# %% [markdown]
# ## Planner (deterministic rules)
# Maps a task dict to a single tool call.

# %%
def planner(task):
    """Map task dict to a single tool call step.
    Example: [{'tool': 'sum_array', 'args': {'arr': np.array([...])}}]
    """
    pass

# %% [markdown]
# ## Agent (approval + step limit + logging)

# %%
class SimpleAgent:
    def __init__(self, allowed_tools, max_steps):
        """Store config and initialise logs.
        """
        pass
    def run(self, task):
        """Require approval; generate plan; enforce max steps and allowed tools; log minimal metadata; return output.
        """
        pass

# %% [markdown]
# ## Tests

# %%
# Suggested self-checks (uncomment after implementation)
# agent = SimpleAgent(ALLOWED_TOOLS, MAX_STEPS)
# outs = [agent.run(t) for t in TASKS]
# print('outs:', outs)
# assert isinstance(outs[0], float)
# assert np.array_equal(outs[1], np.array([0,1,0]))
# assert outs[2] is None
